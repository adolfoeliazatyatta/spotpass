# %% [markdown]
# Autor: Adolfo Eliazat
#
# Assunto: Ingestão dos arquivos csvs com dados de transações
#
# Atualizações:

# %%
import requests, json 
from pyspark.sql import SparkSession
from pyspark.sql.functions import explode
from datetime import datetime, date, timedelta
from pyspark.sql.types import StructType, StructField, StringType, DoubleType, IntegerType, ArrayType
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 16, Finished, Available)

# %%
spark = SparkSession.builder \
    .master('local') \
    .appName('NOTEBOOK_SPOTPASS_LOAD_API_EVENTS_FULL') \
    .config('spark.executor.memory', '5gb') \
    .config("spark.cores.max", "6") \
    .config("spark.sql.legacy.timeParserPolicy", "LEGACY") \
    .config("park.sql.parquet.datetimeRebaseModeInWrite", "LEGACY") \
    .config("spark.microsoft.delta.optimizeWrite.enabled", "true") \
    .config("spark.sql.parquet.vorder.enabled", "true") \
    .getOrCreate()
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 4, Finished, Available)

# %%
write_setup = {
    "compression": "gzip",  # Use "gzip" em vez de "snappy" para a compressão
    "maxRecordsPerFile": 500000,  # Limita o número de registros por arquivo
    "spark.sql.files.maxPartitionBytes": "128m",  # Define o tamanho máximo de cada partição
    "spark.sql.parquet.output.committer.class": "org.apache.spark.sql.parquet.DirectParquetOutputCommitter"  # Usa um commiter mais consistente
}
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 5, Finished, Available)

# %% [markdown]
# **Configurações de data e hora**

# %%
date_time = ( datetime.now() - timedelta(days=1))
date = date_time.strftime('%Y-%m-%d')
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 6, Finished, Available)

# %%
delta_table_name = "Tables/spotpass_operations"
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 7, Finished, Available)

# %%
# Define the schema for the JSON data
schema = StructType([
    StructField("id", IntegerType(), True),
    StructField("operation_type", StringType(), True),
    StructField("operation_date", StringType(), True),
    StructField("total", StringType(), True),
    StructField("created_at", StringType(), True),
    StructField("updated_at", StringType(), True),
    StructField("pos_information", StructType([
        StructField("event", StructType([
            StructField("id", StringType(), True),
            StructField("event_type", StringType(), True),
            StructField("name", StringType(), True),
            StructField("start_date", StringType(), True),
            StructField("end_date", StringType(), True)
        ]), True)
    ]), True),
    StructField("operation_items", ArrayType(StructType([
        StructField("quantity", StringType(), True),
        StructField("unit_price", StringType(), True),
        StructField("product_name", StringType(), True),
        StructField("category_name", StringType(), True),
        StructField("created_at", StringType(), True),
        StructField("updated_at", StringType(), True)
    ])), True),
    StructField("payments", ArrayType(StructType([
        StructField("total", StringType(), True),
        StructField("installments", IntegerType(), True),
        StructField("payment_type_name", StringType(), True),
        StructField("acquirer", StringType(), True),
        StructField("primary_code", StringType(), True),
        StructField("status", StringType(), True),
        StructField("date", StringType(), True)
    ])), True),
    StructField("invoice", StringType(), True)
])
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 10, Finished, Available)

# %%
# Function to fetch data for a given page
def fetch_data(url):
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        return json.loads(response.text)
    else:
        print(f"Error fetching data from {url}")
        return None

# Function to extract events from response data
def extract_operations(response_data):
    if response_data is None:
        return []
    return response_data.get("content", [])
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 13, Finished, Available)

# %%
# Create a Spark session
spark = SparkSession.builder \
    .appName("API Pagination") \
    .getOrCreate()

# Define the base URL
base_url = "https://public.api.spotpass.com.br/operations"

# Define the headers
headers = {
    "accept": "application/json",
    "content-type": "application/json",
    "AUTHORIZATION": "QM6Gv1kKYzHzhkvPzjbYmzGz"
}

# List to store all operations
all_operations = []

# Variable to track pagination
page = 1

# Loop to fetch all pages
while True:
    url = f"{base_url}?page={page}"
    print(f"Fetching data from {url}")

    # Fetch data for the current page
    response_data = fetch_data(url)
    
    # Extract operations from the response
    operations = extract_operations(response_data)
    
    # If no operations are returned, break the loop
    if not operations:
        break
    
    # Extend the list of all operations with the operations from the current page
    all_operations.extend(operations)
    
    # Increment page for the next iteration
    page += 1

# Create DataFrame from all operations
df = spark.createDataFrame(all_operations, schema)

df = df.withColumn("event_id", df["pos_information.event.id"]) \
       .withColumn("event_type", df["pos_information.event.event_type"]) \
       .withColumn("event_name", df["pos_information.event.name"]) \
       .withColumn("event_start_date", df["pos_information.event.start_date"]) \
       .withColumn("event_end_date", df["pos_information.event.end_date"]) \
       .drop("pos_information")

# Explode the operation_items column
df = df.withColumn("exploded_items", explode(df["operation_items"])) \
       .withColumn("quantity", df["exploded_items.quantity"]) \
       .withColumn("unit_price", df["exploded_items.unit_price"]) \
       .withColumn("product_name", df["exploded_items.product_name"]) \
       .withColumn("category_name", df["exploded_items.category_name"]) \
       .withColumn("item_created_at", df["exploded_items.created_at"]) \
       .withColumn("item_updated_at", df["exploded_items.updated_at"]) \
       .drop("operation_items") \
       .drop("exploded_items")
       
# Show the DataFrame
#df_operations_events_exploded.show(truncate=False)
# Out:
# StatementMeta(, bfd6a0b8-25b2-42a6-ac45-93c18669abd6, 24, Submitted, Running)
# Fetching data from https://public.api.spotpass.com.br/operations?page=1
# Fetching data from https://public.api.spotpass.com.br/operations?page=2
# Fetching data from https://public.api.spotpass.com.br/operations?page=3
# Fetching data from https://public.api.spotpass.com.br/operations?page=4
# Fetching data from https://public.api.spotpass.com.br/operations?page=5
# Fetching data from https://public.api.spotpass.com.br/operations?page=6
# Fetching data from https://public.api.spotpass.com.br/operations?page=7
# Fetching data from https://public.api.spotpass.com.br/operations?page=8
# Fetching data from https://public.api.spotpass.com.br/operations?page=9
# Fetching data from https://public.api.spotpass.com.br/operations?page=10
# Fetching data from https://public.api.spotpass.com.br/operations?page=11
# Fetching data from https://public.api.spotpass.com.br/operations?page=12
# Fetching data from https://public.api.spotpass.com.br/operations?page=13
# Fetching data from https://public.api.spotpass.com.br/operations?page=14
# Fetching data from https://public.api.spotpass.com.br/operations?page=15
# Fetching data from https://public.api.spotpass.com.br/operations?page=16
# Fetching data from https://public.api.spotpass.com.br/operations?page=17
# Fetching data from https://public.api.spotpass.com.br/operations?page=18
# Fetching data from https://public.api.spotpass.com.br/operations?page=19
# Fetching data from https://public.api.spotpass.com.br/operations?page=20
# Fetching data from https://public.api.spotpass.com.br/operations?page=21
# Fetching data from https://public.api.spotpass.com.br/operations?page=22
# Fetching data from https://public.api.spotpass.com.br/operations?page=23
# Fetching data from https://public.api.spotpass.com.br/operations?page=24
# Fetching data from https://public.api.spotpass.com.br/operations?page=25
# Fetching data from https://public.api.spotpass.com.br/operations?page=26
# Fetching data from https://public.api.spotpass.com.br/operations?page=27
# Fetching data from https://public.api.spotpass.com.br/operations?page=28
# Fetching data from https://public.api.spotpass.com.br/operations?page=29
# Fetching data from https://public.api.spotpass.com.br/operations?page=30
# Fetching data from https://public.api.spotpass.com.br/operations?page=31
# Fetching data from https://public.api.spotpass.com.br/operations?page=32
# Fetching data from https://public.api.spotpass.com.br/operations?page=33
# Fetching data from https://public.api.spotpass.com.br/operations?page=34
# Fetching data from https://public.api.spotpass.com.br/operations?page=35
# Fetching data from https://public.api.spotpass.com.br/operations?page=36
# Fetching data from https://public.api.spotpass.com.br/operations?page=37
# Fetching data from https://public.api.spotpass.com.br/operations?page=38
# Fetching data from https://public.api.spotpass.com.br/operations?page=39
# Fetching data from https://public.api.spotpass.com.br/operations?page=40
# Fetching data from https://public.api.spotpass.com.br/operations?page=41
# Fetching data from https://public.api.spotpass.com.br/operations?page=42
# Fetching data from https://public.api.spotpass.com.br/operations?page=43
# Fetching data from https://public.api.spotpass.com.br/operations?page=44
# Fetching data from https://public.api.spotpass.com.br/operations?page=45
# Fetching data from https://public.api.spotpass.com.br/operations?page=46
# Fetching data from https://public.api.spotpass.com.br/operations?page=47
# Fetching data from https://public.api.spotpass.com.br/operations?page=48
# Fetching data from https://public.api.spotpass.com.br/operations?page=49
# Fetching data from https://public.api.spotpass.com.br/operations?page=50
# Fetching data from https://public.api.spotpass.com.br/operations?page=51
# Fetching data from https://public.api.spotpass.com.br/operations?page=52
# Fetching data from https://public.api.spotpass.com.br/operations?page=53
# Fetching data from https://public.api.spotpass.com.br/operations?page=54
# Fetching data from https://public.api.spotpass.com.br/operations?page=55
# Fetching data from https://public.api.spotpass.com.br/operations?page=56
# Fetching data from https://public.api.spotpass.com.br/operations?page=57
# Fetching data from https://public.api.spotpass.com.br/operations?page=58
# Fetching data from https://public.api.spotpass.com.br/operations?page=59
# Fetching data from https://public.api.spotpass.com.br/operations?page=60
# Fetching data from https://public.api.spotpass.com.br/operations?page=61
# Fetching data from https://public.api.spotpass.com.br/operations?page=62
# Fetching data from https://public.api.spotpass.com.br/operations?page=63
# Fetching data from https://public.api.spotpass.com.br/operations?page=64
# Fetching data from https://public.api.spotpass.com.br/operations?page=65
# Fetching data from https://public.api.spotpass.com.br/operations?page=66
# Fetching data from https://public.api.spotpass.com.br/operations?page=67
# Fetching data from https://public.api.spotpass.com.br/operations?page=68
# Fetching data from https://public.api.spotpass.com.br/operations?page=69
# Fetching data from https://public.api.spotpass.com.br/operations?page=70
# Fetching data from https://public.api.spotpass.com.br/operations?page=71
# Fetching data from https://public.api.spotpass.com.br/operations?page=72
# Fetching data from https://public.api.spotpass.com.br/operations?page=73
# Fetching data from https://public.api.spotpass.com.br/operations?page=74
# Fetching data from https://public.api.spotpass.com.br/operations?page=75
# Fetching data from https://public.api.spotpass.com.br/operations?page=76
# Fetching data from https://public.api.spotpass.com.br/operations?page=77
# Fetching data from https://public.api.spotpass.com.br/operations?page=78
# Fetching data from https://public.api.spotpass.com.br/operations?page=79
# Fetching data from https://public.api.spotpass.com.br/operations?page=80
# Fetching data from https://public.api.spotpass.com.br/operations?page=81
# Fetching data from https://public.api.spotpass.com.br/operations?page=82
# Fetching data from https://public.api.spotpass.com.br/operations?page=83
# Fetching data from https://public.api.spotpass.com.br/operations?page=84
# Fetching data from https://public.api.spotpass.com.br/operations?page=85
# Fetching data from https://public.api.spotpass.com.br/operations?page=86
# Fetching data from https://public.api.spotpass.com.br/operations?page=87
# Fetching data from https://public.api.spotpass.com.br/operations?page=88
# Fetching data from https://public.api.spotpass.com.br/operations?page=89
# Fetching data from https://public.api.spotpass.com.br/operations?page=90
# Fetching data from https://public.api.spotpass.com.br/operations?page=91
# Fetching data from https://public.api.spotpass.com.br/operations?page=92
# Fetching data from https://public.api.spotpass.com.br/operations?page=93
# Fetching data from https://public.api.spotpass.com.br/operations?page=94
# Fetching data from https://public.api.spotpass.com.br/operations?page=95
# Fetching data from https://public.api.spotpass.com.br/operations?page=96
# Fetching data from https://public.api.spotpass.com.br/operations?page=97
# Fetching data from https://public.api.spotpass.com.br/operations?page=98
# Fetching data from https://public.api.spotpass.com.br/operations?page=99
# Fetching data from https://public.api.spotpass.com.br/operations?page=100
# Fetching data from https://public.api.spotpass.com.br/operations?page=101
# Fetching data from https://public.api.spotpass.com.br/operations?page=102
# Fetching data from https://public.api.spotpass.com.br/operations?page=103
# Fetching data from https://public.api.spotpass.com.br/operations?page=104
# Fetching data from https://public.api.spotpass.com.br/operations?page=105
# Fetching data from https://public.api.spotpass.com.br/operations?page=106
# Fetching data from https://public.api.spotpass.com.br/operations?page=107
# Fetching data from https://public.api.spotpass.com.br/operations?page=108
# Fetching data from https://public.api.spotpass.com.br/operations?page=109
# Fetching data from https://public.api.spotpass.com.br/operations?page=110
# Fetching data from https://public.api.spotpass.com.br/operations?page=111
# Fetching data from https://public.api.spotpass.com.br/operations?page=112
# Fetching data from https://public.api.spotpass.com.br/operations?page=113
# Fetching data from https://public.api.spotpass.com.br/operations?page=114
# Fetching data from https://public.api.spotpass.com.br/operations?page=115
# Fetching data from https://public.api.spotpass.com.br/operations?page=116
# Fetching data from https://public.api.spotpass.com.br/operations?page=117
# Fetching data from https://public.api.spotpass.com.br/operations?page=118
# Fetching data from https://public.api.spotpass.com.br/operations?page=119
# Fetching data from https://public.api.spotpass.com.br/operations?page=120
# Fetching data from https://public.api.spotpass.com.br/operations?page=121
# Fetching data from https://public.api.spotpass.com.br/operations?page=122
# Fetching data from https://public.api.spotpass.com.br/operations?page=123
# Fetching data from https://public.api.spotpass.com.br/operations?page=124
# Fetching data from https://public.api.spotpass.com.br/operations?page=125
# Fetching data from https://public.api.spotpass.com.br/operations?page=126
# Fetching data from https://public.api.spotpass.com.br/operations?page=127
# Fetching data from https://public.api.spotpass.com.br/operations?page=128
# Fetching data from https://public.api.spotpass.com.br/operations?page=129
# Fetching data from https://public.api.spotpass.com.br/operations?page=130
# Fetching data from https://public.api.spotpass.com.br/operations?page=131
# Fetching data from https://public.api.spotpass.com.br/operations?page=132
# Fetching data from https://public.api.spotpass.com.br/operations?page=133
# Fetching data from https://public.api.spotpass.com.br/operations?page=134
# Fetching data from https://public.api.spotpass.com.br/operations?page=135
# Fetching data from https://public.api.spotpass.com.br/operations?page=136
# Fetching data from https://public.api.spotpass.com.br/operations?page=137
# Fetching data from https://public.api.spotpass.com.br/operations?page=138
# Fetching data from https://public.api.spotpass.com.br/operations?page=139
# Fetching data from https://public.api.spotpass.com.br/operations?page=140
# Fetching data from https://public.api.spotpass.com.br/operations?page=141
# Fetching data from https://public.api.spotpass.com.br/operations?page=142
# Fetching data from https://public.api.spotpass.com.br/operations?page=143
# Fetching data from https://public.api.spotpass.com.br/operations?page=144
# Fetching data from https://public.api.spotpass.com.br/operations?page=145
# Fetching data from https://public.api.spotpass.com.br/operations?page=146
# Fetching data from https://public.api.spotpass.com.br/operations?page=147
# Fetching data from https://public.api.spotpass.com.br/operations?page=148
# Fetching data from https://public.api.spotpass.com.br/operations?page=149
# Fetching data from https://public.api.spotpass.com.br/operations?page=150
# Fetching data from https://public.api.spotpass.com.br/operations?page=151
# Fetching data from https://public.api.spotpass.com.br/operations?page=152
# Fetching data from https://public.api.spotpass.com.br/operations?page=153
# Fetching data from https://public.api.spotpass.com.br/operations?page=154
# Fetching data from https://public.api.spotpass.com.br/operations?page=155
# Fetching data from https://public.api.spotpass.com.br/operations?page=156
# Fetching data from https://public.api.spotpass.com.br/operations?page=157
# Fetching data from https://public.api.spotpass.com.br/operations?page=158
# Fetching data from https://public.api.spotpass.com.br/operations?page=159
# Fetching data from https://public.api.spotpass.com.br/operations?page=160
# Fetching data from https://public.api.spotpass.com.br/operations?page=161
# Fetching data from https://public.api.spotpass.com.br/operations?page=162
# Fetching data from https://public.api.spotpass.com.br/operations?page=163
# Fetching data from https://public.api.spotpass.com.br/operations?page=164
# Fetching data from https://public.api.spotpass.com.br/operations?page=165
# Fetching data from https://public.api.spotpass.com.br/operations?page=166
# Fetching data from https://public.api.spotpass.com.br/operations?page=167
# Fetching data from https://public.api.spotpass.com.br/operations?page=168
# Fetching data from https://public.api.spotpass.com.br/operations?page=169
# Fetching data from https://public.api.spotpass.com.br/operations?page=170
# Fetching data from https://public.api.spotpass.com.br/operations?page=171
# Fetching data from https://public.api.spotpass.com.br/operations?page=172
# Fetching data from https://public.api.spotpass.com.br/operations?page=173
# Fetching data from https://public.api.spotpass.com.br/operations?page=174
# Fetching data from https://public.api.spotpass.com.br/operations?page=175
# Fetching data from https://public.api.spotpass.com.br/operations?page=176
# Fetching data from https://public.api.spotpass.com.br/operations?page=177
# Fetching data from https://public.api.spotpass.com.br/operations?page=178
# Fetching data from https://public.api.spotpass.com.br/operations?page=179
# Fetching data from https://public.api.spotpass.com.br/operations?page=180
# Fetching data from https://public.api.spotpass.com.br/operations?page=181
# Fetching data from https://public.api.spotpass.com.br/operations?page=182
# Fetching data from https://public.api.spotpass.com.br/operations?page=183
# Fetching data from https://public.api.spotpass.com.br/operations?page=184
# Fetching data from https://public.api.spotpass.com.br/operations?page=185
# Fetching data from https://public.api.spotpass.com.br/operations?page=186
# Fetching data from https://public.api.spotpass.com.br/operations?page=187
# Fetching data from https://public.api.spotpass.com.br/operations?page=188
# Fetching data from https://public.api.spotpass.com.br/operations?page=189
# Fetching data from https://public.api.spotpass.com.br/operations?page=190
# Fetching data from https://public.api.spotpass.com.br/operations?page=191
# Fetching data from https://public.api.spotpass.com.br/operations?page=192
# Fetching data from https://public.api.spotpass.com.br/operations?page=193
# Fetching data from https://public.api.spotpass.com.br/operations?page=194
# Fetching data from https://public.api.spotpass.com.br/operations?page=195
# Fetching data from https://public.api.spotpass.com.br/operations?page=196
# Fetching data from https://public.api.spotpass.com.br/operations?page=197
# Fetching data from https://public.api.spotpass.com.br/operations?page=198
# Fetching data from https://public.api.spotpass.com.br/operations?page=199
# Fetching data from https://public.api.spotpass.com.br/operations?page=200
# Fetching data from https://public.api.spotpass.com.br/operations?page=201
# Fetching data from https://public.api.spotpass.com.br/operations?page=202
# Fetching data from https://public.api.spotpass.com.br/operations?page=203
# Fetching data from https://public.api.spotpass.com.br/operations?page=204
# Fetching data from https://public.api.spotpass.com.br/operations?page=205
# Fetching data from https://public.api.spotpass.com.br/operations?page=206
# Fetching data from https://public.api.spotpass.com.br/operations?page=207
# Fetching data from https://public.api.spotpass.com.br/operations?page=208
# Fetching data from https://public.api.spotpass.com.br/operations?page=209
# Fetching data from https://public.api.spotpass.com.br/operations?page=210
# Fetching data from https://public.api.spotpass.com.br/operations?page=211
# Fetching data from https://public.api.spotpass.com.br/operations?page=212
# Fetching data from https://public.api.spotpass.com.br/operations?page=213
# Fetching data from https://public.api.spotpass.com.br/operations?page=214
# Fetching data from https://public.api.spotpass.com.br/operations?page=215
# Fetching data from https://public.api.spotpass.com.br/operations?page=216
# Fetching data from https://public.api.spotpass.com.br/operations?page=217
# Fetching data from https://public.api.spotpass.com.br/operations?page=218
# Fetching data from https://public.api.spotpass.com.br/operations?page=219
# Fetching data from https://public.api.spotpass.com.br/operations?page=220
# Fetching data from https://public.api.spotpass.com.br/operations?page=221
# Fetching data from https://public.api.spotpass.com.br/operations?page=222
# Fetching data from https://public.api.spotpass.com.br/operations?page=223
# Fetching data from https://public.api.spotpass.com.br/operations?page=224
# Fetching data from https://public.api.spotpass.com.br/operations?page=225
# Fetching data from https://public.api.spotpass.com.br/operations?page=226
# Fetching data from https://public.api.spotpass.com.br/operations?page=227
# Fetching data from https://public.api.spotpass.com.br/operations?page=228
# Fetching data from https://public.api.spotpass.com.br/operations?page=229
# Fetching data from https://public.api.spotpass.com.br/operations?page=230
# Fetching data from https://public.api.spotpass.com.br/operations?page=231
# Fetching data from https://public.api.spotpass.com.br/operations?page=232
# Fetching data from https://public.api.spotpass.com.br/operations?page=233
# Fetching data from https://public.api.spotpass.com.br/operations?page=234
# Fetching data from https://public.api.spotpass.com.br/operations?page=235
# Fetching data from https://public.api.spotpass.com.br/operations?page=236
# Fetching data from https://public.api.spotpass.com.br/operations?page=237
# Fetching data from https://public.api.spotpass.com.br/operations?page=238
# Fetching data from https://public.api.spotpass.com.br/operations?page=239
# Fetching data from https://public.api.spotpass.com.br/operations?page=240
# Fetching data from https://public.api.spotpass.com.br/operations?page=241
# Fetching data from https://public.api.spotpass.com.br/operations?page=242
# Fetching data from https://public.api.spotpass.com.br/operations?page=243
# Fetching data from https://public.api.spotpass.com.br/operations?page=244
# Fetching data from https://public.api.spotpass.com.br/operations?page=245
# Fetching data from https://public.api.spotpass.com.br/operations?page=246
# Fetching data from https://public.api.spotpass.com.br/operations?page=247
# Fetching data from https://public.api.spotpass.com.br/operations?page=248
# Fetching data from https://public.api.spotpass.com.br/operations?page=249
# Fetching data from https://public.api.spotpass.com.br/operations?page=250
# Fetching data from https://public.api.spotpass.com.br/operations?page=251
# Fetching data from https://public.api.spotpass.com.br/operations?page=252
# Fetching data from https://public.api.spotpass.com.br/operations?page=253
# Fetching data from https://public.api.spotpass.com.br/operations?page=254
# Fetching data from https://public.api.spotpass.com.br/operations?page=255
# Fetching data from https://public.api.spotpass.com.br/operations?page=256
# Fetching data from https://public.api.spotpass.com.br/operations?page=257
# Fetching data from https://public.api.spotpass.com.br/operations?page=258
# Fetching data from https://public.api.spotpass.com.br/operations?page=259
# Fetching data from https://public.api.spotpass.com.br/operations?page=260
# Fetching data from https://public.api.spotpass.com.br/operations?page=261
# Fetching data from https://public.api.spotpass.com.br/operations?page=262
# Fetching data from https://public.api.spotpass.com.br/operations?page=263
# Fetching data from https://public.api.spotpass.com.br/operations?page=264
# Fetching data from https://public.api.spotpass.com.br/operations?page=265
# Fetching data from https://public.api.spotpass.com.br/operations?page=266
# Fetching data from https://public.api.spotpass.com.br/operations?page=267
# Fetching data from https://public.api.spotpass.com.br/operations?page=268
# Fetching data from https://public.api.spotpass.com.br/operations?page=269
# Fetching data from https://public.api.spotpass.com.br/operations?page=270
# Fetching data from https://public.api.spotpass.com.br/operations?page=271
# Fetching data from https://public.api.spotpass.com.br/operations?page=272
# Fetching data from https://public.api.spotpass.com.br/operations?page=273
# Fetching data from https://public.api.spotpass.com.br/operations?page=274
# Fetching data from https://public.api.spotpass.com.br/operations?page=275
# Fetching data from https://public.api.spotpass.com.br/operations?page=276
# Fetching data from https://public.api.spotpass.com.br/operations?page=277
# Fetching data from https://public.api.spotpass.com.br/operations?page=278
# Fetching data from https://public.api.spotpass.com.br/operations?page=279
# Fetching data from https://public.api.spotpass.com.br/operations?page=280
# Fetching data from https://public.api.spotpass.com.br/operations?page=281
# Fetching data from https://public.api.spotpass.com.br/operations?page=282
# Fetching data from https://public.api.spotpass.com.br/operations?page=283
# Fetching data from https://public.api.spotpass.com.br/operations?page=284
# Fetching data from https://public.api.spotpass.com.br/operations?page=285
# Fetching data from https://public.api.spotpass.com.br/operations?page=286
# Fetching data from https://public.api.spotpass.com.br/operations?page=287
# Fetching data from https://public.api.spotpass.com.br/operations?page=288
# Fetching data from https://public.api.spotpass.com.br/operations?page=289
# Fetching data from https://public.api.spotpass.com.br/operations?page=290
# Fetching data from https://public.api.spotpass.com.br/operations?page=291
# Fetching data from https://public.api.spotpass.com.br/operations?page=292
# Fetching data from https://public.api.spotpass.com.br/operations?page=293
# Fetching data from https://public.api.spotpass.com.br/operations?page=294
# Fetching data from https://public.api.spotpass.com.br/operations?page=295
# Fetching data from https://public.api.spotpass.com.br/operations?page=296
# Fetching data from https://public.api.spotpass.com.br/operations?page=297
# Fetching data from https://public.api.spotpass.com.br/operations?page=298
# Fetching data from https://public.api.spotpass.com.br/operations?page=299
# Fetching data from https://public.api.spotpass.com.br/operations?page=300
# Fetching data from https://public.api.spotpass.com.br/operations?page=301
# Fetching data from https://public.api.spotpass.com.br/operations?page=302
# Fetching data from https://public.api.spotpass.com.br/operations?page=303
# Fetching data from https://public.api.spotpass.com.br/operations?page=304
# Fetching data from https://public.api.spotpass.com.br/operations?page=305
# Fetching data from https://public.api.spotpass.com.br/operations?page=306
# Fetching data from https://public.api.spotpass.com.br/operations?page=307
# Fetching data from https://public.api.spotpass.com.br/operations?page=308
# Fetching data from https://public.api.spotpass.com.br/operations?page=309
# Fetching data from https://public.api.spotpass.com.br/operations?page=310
# Fetching data from https://public.api.spotpass.com.br/operations?page=311
# Fetching data from https://public.api.spotpass.com.br/operations?page=312
# Fetching data from https://public.api.spotpass.com.br/operations?page=313
# Fetching data from https://public.api.spotpass.com.br/operations?page=314
# Fetching data from https://public.api.spotpass.com.br/operations?page=315
# Fetching data from https://public.api.spotpass.com.br/operations?page=316
# Fetching data from https://public.api.spotpass.com.br/operations?page=317
# Fetching data from https://public.api.spotpass.com.br/operations?page=318
# Fetching data from https://public.api.spotpass.com.br/operations?page=319
# Fetching data from https://public.api.spotpass.com.br/operations?page=320
# Fetching data from https://public.api.spotpass.com.br/operations?page=321
# Fetching data from https://public.api.spotpass.com.br/operations?page=322
# Fetching data from https://public.api.spotpass.com.br/operations?page=323
# Fetching data from https://public.api.spotpass.com.br/operations?page=324
# Fetching data from https://public.api.spotpass.com.br/operations?page=325
# Fetching data from https://public.api.spotpass.com.br/operations?page=326
# Fetching data from https://public.api.spotpass.com.br/operations?page=327
# Fetching data from https://public.api.spotpass.com.br/operations?page=328
# Fetching data from https://public.api.spotpass.com.br/operations?page=329
# Fetching data from https://public.api.spotpass.com.br/operations?page=330
# Fetching data from https://public.api.spotpass.com.br/operations?page=331
# Fetching data from https://public.api.spotpass.com.br/operations?page=332
# Fetching data from https://public.api.spotpass.com.br/operations?page=333
# Fetching data from https://public.api.spotpass.com.br/operations?page=334
# Fetching data from https://public.api.spotpass.com.br/operations?page=335
# Fetching data from https://public.api.spotpass.com.br/operations?page=336
# Fetching data from https://public.api.spotpass.com.br/operations?page=337
# Fetching data from https://public.api.spotpass.com.br/operations?page=338
# Fetching data from https://public.api.spotpass.com.br/operations?page=339
# Fetching data from https://public.api.spotpass.com.br/operations?page=340
# Fetching data from https://public.api.spotpass.com.br/operations?page=341
# Fetching data from https://public.api.spotpass.com.br/operations?page=342
# Fetching data from https://public.api.spotpass.com.br/operations?page=343
# Fetching data from https://public.api.spotpass.com.br/operations?page=344
# Fetching data from https://public.api.spotpass.com.br/operations?page=345
# Fetching data from https://public.api.spotpass.com.br/operations?page=346
# Fetching data from https://public.api.spotpass.com.br/operations?page=347
# Fetching data from https://public.api.spotpass.com.br/operations?page=348
# Fetching data from https://public.api.spotpass.com.br/operations?page=349
# Fetching data from https://public.api.spotpass.com.br/operations?page=350
# Fetching data from https://public.api.spotpass.com.br/operations?page=351
# Fetching data from https://public.api.spotpass.com.br/operations?page=352
# Fetching data from https://public.api.spotpass.com.br/operations?page=353
# Fetching data from https://public.api.spotpass.com.br/operations?page=354
# Fetching data from https://public.api.spotpass.com.br/operations?page=355
# Fetching data from https://public.api.spotpass.com.br/operations?page=356
# Fetching data from https://public.api.spotpass.com.br/operations?page=357
# Fetching data from https://public.api.spotpass.com.br/operations?page=358
# Fetching data from https://public.api.spotpass.com.br/operations?page=359
# Fetching data from https://public.api.spotpass.com.br/operations?page=360
# Fetching data from https://public.api.spotpass.com.br/operations?page=361
# Fetching data from https://public.api.spotpass.com.br/operations?page=362
# Fetching data from https://public.api.spotpass.com.br/operations?page=363
# Fetching data from https://public.api.spotpass.com.br/operations?page=364
# Fetching data from https://public.api.spotpass.com.br/operations?page=365
# Fetching data from https://public.api.spotpass.com.br/operations?page=366
# Fetching data from https://public.api.spotpass.com.br/operations?page=367
# Fetching data from https://public.api.spotpass.com.br/operations?page=368
# Fetching data from https://public.api.spotpass.com.br/operations?page=369
# Fetching data from https://public.api.spotpass.com.br/operations?page=370
# Fetching data from https://public.api.spotpass.com.br/operations?page=371
# Fetching data from https://public.api.spotpass.com.br/operations?page=372
# Fetching data from https://public.api.spotpass.com.br/operations?page=373
# Fetching data from https://public.api.spotpass.com.br/operations?page=374
# Fetching data from https://public.api.spotpass.com.br/operations?page=375
# Fetching data from https://public.api.spotpass.com.br/operations?page=376
# Fetching data from https://public.api.spotpass.com.br/operations?page=377
# Fetching data from https://public.api.spotpass.com.br/operations?page=378
# Fetching data from https://public.api.spotpass.com.br/operations?page=379
# Fetching data from https://public.api.spotpass.com.br/operations?page=380
# Fetching data from https://public.api.spotpass.com.br/operations?page=381
# Fetching data from https://public.api.spotpass.com.br/operations?page=382
# Fetching data from https://public.api.spotpass.com.br/operations?page=383
# Fetching data from https://public.api.spotpass.com.br/operations?page=384
# Fetching data from https://public.api.spotpass.com.br/operations?page=385
# Fetching data from https://public.api.spotpass.com.br/operations?page=386
# Fetching data from https://public.api.spotpass.com.br/operations?page=387
# Fetching data from https://public.api.spotpass.com.br/operations?page=388
# Fetching data from https://public.api.spotpass.com.br/operations?page=389
# Fetching data from https://public.api.spotpass.com.br/operations?page=390
# Fetching data from https://public.api.spotpass.com.br/operations?page=391
# Fetching data from https://public.api.spotpass.com.br/operations?page=392
# Fetching data from https://public.api.spotpass.com.br/operations?page=393
# Fetching data from https://public.api.spotpass.com.br/operations?page=394
# Fetching data from https://public.api.spotpass.com.br/operations?page=395
# Fetching data from https://public.api.spotpass.com.br/operations?page=396
# Fetching data from https://public.api.spotpass.com.br/operations?page=397
# Fetching data from https://public.api.spotpass.com.br/operations?page=398
# Fetching data from https://public.api.spotpass.com.br/operations?page=399
# Fetching data from https://public.api.spotpass.com.br/operations?page=400
# Fetching data from https://public.api.spotpass.com.br/operations?page=401
# Fetching data from https://public.api.spotpass.com.br/operations?page=402
# Fetching data from https://public.api.spotpass.com.br/operations?page=403
# Fetching data from https://public.api.spotpass.com.br/operations?page=404
# Fetching data from https://public.api.spotpass.com.br/operations?page=405
# Fetching data from https://public.api.spotpass.com.br/operations?page=406
# Fetching data from https://public.api.spotpass.com.br/operations?page=407
# Fetching data from https://public.api.spotpass.com.br/operations?page=408
# Fetching data from https://public.api.spotpass.com.br/operations?page=409
# Fetching data from https://public.api.spotpass.com.br/operations?page=410
# Fetching data from https://public.api.spotpass.com.br/operations?page=411
# Fetching data from https://public.api.spotpass.com.br/operations?page=412
# Fetching data from https://public.api.spotpass.com.br/operations?page=413
# Fetching data from https://public.api.spotpass.com.br/operations?page=414
# Fetching data from https://public.api.spotpass.com.br/operations?page=415
# Fetching data from https://public.api.spotpass.com.br/operations?page=416
# Fetching data from https://public.api.spotpass.com.br/operations?page=417
# Fetching data from https://public.api.spotpass.com.br/operations?page=418
# Fetching data from https://public.api.spotpass.com.br/operations?page=419
# Fetching data from https://public.api.spotpass.com.br/operations?page=420
# Fetching data from https://public.api.spotpass.com.br/operations?page=421
# Fetching data from https://public.api.spotpass.com.br/operations?page=422
# Fetching data from https://public.api.spotpass.com.br/operations?page=423
# Fetching data from https://public.api.spotpass.com.br/operations?page=424
# Fetching data from https://public.api.spotpass.com.br/operations?page=425
# Fetching data from https://public.api.spotpass.com.br/operations?page=426
# Fetching data from https://public.api.spotpass.com.br/operations?page=427
# Fetching data from https://public.api.spotpass.com.br/operations?page=428
# Fetching data from https://public.api.spotpass.com.br/operations?page=429
# Fetching data from https://public.api.spotpass.com.br/operations?page=430
# Fetching data from https://public.api.spotpass.com.br/operations?page=431
# Fetching data from https://public.api.spotpass.com.br/operations?page=432
# Fetching data from https://public.api.spotpass.com.br/operations?page=433
# Fetching data from https://public.api.spotpass.com.br/operations?page=434
# Fetching data from https://public.api.spotpass.com.br/operations?page=435
# Fetching data from https://public.api.spotpass.com.br/operations?page=436
# Fetching data from https://public.api.spotpass.com.br/operations?page=437
# Fetching data from https://public.api.spotpass.com.br/operations?page=438
# Fetching data from https://public.api.spotpass.com.br/operations?page=439
# Fetching data from https://public.api.spotpass.com.br/operations?page=440
# Fetching data from https://public.api.spotpass.com.br/operations?page=441
# Fetching data from https://public.api.spotpass.com.br/operations?page=442
# Fetching data from https://public.api.spotpass.com.br/operations?page=443
# Fetching data from https://public.api.spotpass.com.br/operations?page=444
# Fetching data from https://public.api.spotpass.com.br/operations?page=445
# Fetching data from https://public.api.spotpass.com.br/operations?page=446
# Fetching data from https://public.api.spotpass.com.br/operations?page=447
# Fetching data from https://public.api.spotpass.com.br/operations?page=448
# Fetching data from https://public.api.spotpass.com.br/operations?page=449
# Fetching data from https://public.api.spotpass.com.br/operations?page=450
# Fetching data from https://public.api.spotpass.com.br/operations?page=451
# Fetching data from https://public.api.spotpass.com.br/operations?page=452
# Fetching data from https://public.api.spotpass.com.br/operations?page=453
# Fetching data from https://public.api.spotpass.com.br/operations?page=454
# Fetching data from https://public.api.spotpass.com.br/operations?page=455
# Fetching data from https://public.api.spotpass.com.br/operations?page=456
# Fetching data from https://public.api.spotpass.com.br/operations?page=457
# Fetching data from https://public.api.spotpass.com.br/operations?page=458
# Fetching data from https://public.api.spotpass.com.br/operations?page=459
# Fetching data from https://public.api.spotpass.com.br/operations?page=460
# Fetching data from https://public.api.spotpass.com.br/operations?page=461
# Fetching data from https://public.api.spotpass.com.br/operations?page=462
# Fetching data from https://public.api.spotpass.com.br/operations?page=463
# Fetching data from https://public.api.spotpass.com.br/operations?page=464
# Fetching data from https://public.api.spotpass.com.br/operations?page=465
# Fetching data from https://public.api.spotpass.com.br/operations?page=466
# Fetching data from https://public.api.spotpass.com.br/operations?page=467
# Fetching data from https://public.api.spotpass.com.br/operations?page=468
# Fetching data from https://public.api.spotpass.com.br/operations?page=469
# Fetching data from https://public.api.spotpass.com.br/operations?page=470
# Fetching data from https://public.api.spotpass.com.br/operations?page=471
# Fetching data from https://public.api.spotpass.com.br/operations?page=472
# Fetching data from https://public.api.spotpass.com.br/operations?page=473
# Fetching data from https://public.api.spotpass.com.br/operations?page=474
# Fetching data from https://public.api.spotpass.com.br/operations?page=475
# Fetching data from https://public.api.spotpass.com.br/operations?page=476
# Fetching data from https://public.api.spotpass.com.br/operations?page=477
# Fetching data from https://public.api.spotpass.com.br/operations?page=478
# Fetching data from https://public.api.spotpass.com.br/operations?page=479
# Fetching data from https://public.api.spotpass.com.br/operations?page=480
# Fetching data from https://public.api.spotpass.com.br/operations?page=481
# Fetching data from https://public.api.spotpass.com.br/operations?page=482
# Fetching data from https://public.api.spotpass.com.br/operations?page=483
# Fetching data from https://public.api.spotpass.com.br/operations?page=484
# Fetching data from https://public.api.spotpass.com.br/operations?page=485
# Fetching data from https://public.api.spotpass.com.br/operations?page=486
# Fetching data from https://public.api.spotpass.com.br/operations?page=487
# Fetching data from https://public.api.spotpass.com.br/operations?page=488
# Fetching data from https://public.api.spotpass.com.br/operations?page=489
# Fetching data from https://public.api.spotpass.com.br/operations?page=490
# Fetching data from https://public.api.spotpass.com.br/operations?page=491
# Fetching data from https://public.api.spotpass.com.br/operations?page=492
# Fetching data from https://public.api.spotpass.com.br/operations?page=493
# Fetching data from https://public.api.spotpass.com.br/operations?page=494
# Fetching data from https://public.api.spotpass.com.br/operations?page=495
# Fetching data from https://public.api.spotpass.com.br/operations?page=496
# Fetching data from https://public.api.spotpass.com.br/operations?page=497
# Fetching data from https://public.api.spotpass.com.br/operations?page=498
# Fetching data from https://public.api.spotpass.com.br/operations?page=499
# Fetching data from https://public.api.spotpass.com.br/operations?page=500
# Fetching data from https://public.api.spotpass.com.br/operations?page=501
# Fetching data from https://public.api.spotpass.com.br/operations?page=502
# Fetching data from https://public.api.spotpass.com.br/operations?page=503
# Fetching data from https://public.api.spotpass.com.br/operations?page=504
# Fetching data from https://public.api.spotpass.com.br/operations?page=505
# Fetching data from https://public.api.spotpass.com.br/operations?page=506
# Fetching data from https://public.api.spotpass.com.br/operations?page=507
# Fetching data from https://public.api.spotpass.com.br/operations?page=508
# Fetching data from https://public.api.spotpass.com.br/operations?page=509
# Fetching data from https://public.api.spotpass.com.br/operations?page=510
# Fetching data from https://public.api.spotpass.com.br/operations?page=511
# Fetching data from https://public.api.spotpass.com.br/operations?page=512
# Fetching data from https://public.api.spotpass.com.br/operations?page=513
# Fetching data from https://public.api.spotpass.com.br/operations?page=514
# Fetching data from https://public.api.spotpass.com.br/operations?page=515
# Fetching data from https://public.api.spotpass.com.br/operations?page=516
# Fetching data from https://public.api.spotpass.com.br/operations?page=517
# Fetching data from https://public.api.spotpass.com.br/operations?page=518
# Fetching data from https://public.api.spotpass.com.br/operations?page=519
# Fetching data from https://public.api.spotpass.com.br/operations?page=520
# Fetching data from https://public.api.spotpass.com.br/operations?page=521
# Fetching data from https://public.api.spotpass.com.br/operations?page=522
# Fetching data from https://public.api.spotpass.com.br/operations?page=523
# Fetching data from https://public.api.spotpass.com.br/operations?page=524
# Fetching data from https://public.api.spotpass.com.br/operations?page=525
# Fetching data from https://public.api.spotpass.com.br/operations?page=526
# Fetching data from https://public.api.spotpass.com.br/operations?page=527
# Fetching data from https://public.api.spotpass.com.br/operations?page=528
# Fetching data from https://public.api.spotpass.com.br/operations?page=529
# Fetching data from https://public.api.spotpass.com.br/operations?page=530
# Fetching data from https://public.api.spotpass.com.br/operations?page=531
# Fetching data from https://public.api.spotpass.com.br/operations?page=532
# Fetching data from https://public.api.spotpass.com.br/operations?page=533
# Fetching data from https://public.api.spotpass.com.br/operations?page=534
# Fetching data from https://public.api.spotpass.com.br/operations?page=535
# Fetching data from https://public.api.spotpass.com.br/operations?page=536
# Fetching data from https://public.api.spotpass.com.br/operations?page=537
# Fetching data from https://public.api.spotpass.com.br/operations?page=538
# Fetching data from https://public.api.spotpass.com.br/operations?page=539
# Fetching data from https://public.api.spotpass.com.br/operations?page=540
# Fetching data from https://public.api.spotpass.com.br/operations?page=541
# Fetching data from https://public.api.spotpass.com.br/operations?page=542
# Fetching data from https://public.api.spotpass.com.br/operations?page=543
# Fetching data from https://public.api.spotpass.com.br/operations?page=544
# Fetching data from https://public.api.spotpass.com.br/operations?page=545
# Fetching data from https://public.api.spotpass.com.br/operations?page=546
# Fetching data from https://public.api.spotpass.com.br/operations?page=547
# Fetching data from https://public.api.spotpass.com.br/operations?page=548
# Fetching data from https://public.api.spotpass.com.br/operations?page=549
# Fetching data from https://public.api.spotpass.com.br/operations?page=550
# Fetching data from https://public.api.spotpass.com.br/operations?page=551
# Fetching data from https://public.api.spotpass.com.br/operations?page=552
# Fetching data from https://public.api.spotpass.com.br/operations?page=553
# Fetching data from https://public.api.spotpass.com.br/operations?page=554
# Fetching data from https://public.api.spotpass.com.br/operations?page=555
# Fetching data from https://public.api.spotpass.com.br/operations?page=556
# Fetching data from https://public.api.spotpass.com.br/operations?page=557
# Fetching data from https://public.api.spotpass.com.br/operations?page=558
# Fetching data from https://public.api.spotpass.com.br/operations?page=559
# Fetching data from https://public.api.spotpass.com.br/operations?page=560
# Fetching data from https://public.api.spotpass.com.br/operations?page=561
# Fetching data from https://public.api.spotpass.com.br/operations?page=562
# Fetching data from https://public.api.spotpass.com.br/operations?page=563
# Fetching data from https://public.api.spotpass.com.br/operations?page=564
# Fetching data from https://public.api.spotpass.com.br/operations?page=565
# Fetching data from https://public.api.spotpass.com.br/operations?page=566
# Fetching data from https://public.api.spotpass.com.br/operations?page=567
# Fetching data from https://public.api.spotpass.com.br/operations?page=568
# Fetching data from https://public.api.spotpass.com.br/operations?page=569
# Fetching data from https://public.api.spotpass.com.br/operations?page=570
# Fetching data from https://public.api.spotpass.com.br/operations?page=571
# Fetching data from https://public.api.spotpass.com.br/operations?page=572
# Fetching data from https://public.api.spotpass.com.br/operations?page=573
# Fetching data from https://public.api.spotpass.com.br/operations?page=574
# Fetching data from https://public.api.spotpass.com.br/operations?page=575
# Fetching data from https://public.api.spotpass.com.br/operations?page=576
# Fetching data from https://public.api.spotpass.com.br/operations?page=577
# Fetching data from https://public.api.spotpass.com.br/operations?page=578
# Fetching data from https://public.api.spotpass.com.br/operations?page=579
# Fetching data from https://public.api.spotpass.com.br/operations?page=580
# Fetching data from https://public.api.spotpass.com.br/operations?page=581
# Fetching data from https://public.api.spotpass.com.br/operations?page=582
# Fetching data from https://public.api.spotpass.com.br/operations?page=583
# Fetching data from https://public.api.spotpass.com.br/operations?page=584
# Fetching data from https://public.api.spotpass.com.br/operations?page=585
# Fetching data from https://public.api.spotpass.com.br/operations?page=586
# Fetching data from https://public.api.spotpass.com.br/operations?page=587
# Fetching data from https://public.api.spotpass.com.br/operations?page=588
# Fetching data from https://public.api.spotpass.com.br/operations?page=589
# Fetching data from https://public.api.spotpass.com.br/operations?page=590
# Fetching data from https://public.api.spotpass.com.br/operations?page=591
# Fetching data from https://public.api.spotpass.com.br/operations?page=592
# Fetching data from https://public.api.spotpass.com.br/operations?page=593
# Fetching data from https://public.api.spotpass.com.br/operations?page=594
# Fetching data from https://public.api.spotpass.com.br/operations?page=595
# Fetching data from https://public.api.spotpass.com.br/operations?page=596
# Fetching data from https://public.api.spotpass.com.br/operations?page=597
# Fetching data from https://public.api.spotpass.com.br/operations?page=598
# Fetching data from https://public.api.spotpass.com.br/operations?page=599
# Fetching data from https://public.api.spotpass.com.br/operations?page=600
# Fetching data from https://public.api.spotpass.com.br/operations?page=601
# Fetching data from https://public.api.spotpass.com.br/operations?page=602
# Fetching data from https://public.api.spotpass.com.br/operations?page=603
# Fetching data from https://public.api.spotpass.com.br/operations?page=604
# Fetching data from https://public.api.spotpass.com.br/operations?page=605
# Fetching data from https://public.api.spotpass.com.br/operations?page=606
# Fetching data from https://public.api.spotpass.com.br/operations?page=607
# Fetching data from https://public.api.spotpass.com.br/operations?page=608
# Fetching data from https://public.api.spotpass.com.br/operations?page=609
# Fetching data from https://public.api.spotpass.com.br/operations?page=610
# Fetching data from https://public.api.spotpass.com.br/operations?page=611
# Fetching data from https://public.api.spotpass.com.br/operations?page=612
# Fetching data from https://public.api.spotpass.com.br/operations?page=613
# Fetching data from https://public.api.spotpass.com.br/operations?page=614
# Fetching data from https://public.api.spotpass.com.br/operations?page=615
# Fetching data from https://public.api.spotpass.com.br/operations?page=616
# Fetching data from https://public.api.spotpass.com.br/operations?page=617
# Fetching data from https://public.api.spotpass.com.br/operations?page=618
# Fetching data from https://public.api.spotpass.com.br/operations?page=619
# Fetching data from https://public.api.spotpass.com.br/operations?page=620
# Fetching data from https://public.api.spotpass.com.br/operations?page=621
# Fetching data from https://public.api.spotpass.com.br/operations?page=622
# Fetching data from https://public.api.spotpass.com.br/operations?page=623
# Fetching data from https://public.api.spotpass.com.br/operations?page=624
# Fetching data from https://public.api.spotpass.com.br/operations?page=625
# Fetching data from https://public.api.spotpass.com.br/operations?page=626
# Fetching data from https://public.api.spotpass.com.br/operations?page=627
# Fetching data from https://public.api.spotpass.com.br/operations?page=628
# Fetching data from https://public.api.spotpass.com.br/operations?page=629
# Fetching data from https://public.api.spotpass.com.br/operations?page=630
# Fetching data from https://public.api.spotpass.com.br/operations?page=631
# Fetching data from https://public.api.spotpass.com.br/operations?page=632
# Fetching data from https://public.api.spotpass.com.br/operations?page=633
# Fetching data from https://public.api.spotpass.com.br/operations?page=634
# Fetching data from https://public.api.spotpass.com.br/operations?page=635
# Fetching data from https://public.api.spotpass.com.br/operations?page=636
# Fetching data from https://public.api.spotpass.com.br/operations?page=637
# Fetching data from https://public.api.spotpass.com.br/operations?page=638
# Fetching data from https://public.api.spotpass.com.br/operations?page=639
# Fetching data from https://public.api.spotpass.com.br/operations?page=640
# Fetching data from https://public.api.spotpass.com.br/operations?page=641
# Fetching data from https://public.api.spotpass.com.br/operations?page=642
# Fetching data from https://public.api.spotpass.com.br/operations?page=643
# Fetching data from https://public.api.spotpass.com.br/operations?page=644
# Fetching data from https://public.api.spotpass.com.br/operations?page=645
# Fetching data from https://public.api.spotpass.com.br/operations?page=646
# Fetching data from https://public.api.spotpass.com.br/operations?page=647
# Fetching data from https://public.api.spotpass.com.br/operations?page=648
# Fetching data from https://public.api.spotpass.com.br/operations?page=649
# ...
# Fetching data from https://public.api.spotpass.com.br/operations?page=1453
# Fetching data from https://public.api.spotpass.com.br/operations?page=1454
# Fetching data from https://public.api.spotpass.com.br/operations?page=1455
# Fetching data from https://public.api.spotpass.com.br/operations?page=1456
# Fetching data from https://public.api.spotpass.com.br/operations?page=1457
# Fetching data from https://public.api.spotpass.com.br/operations?page=1458
# Fetching data from https://public.api.spotpass.com.br/operations?page=1459
# Fetching data from https://public.api.spotpass.com.br/operations?page=1460
# Fetching data from https://public.api.spotpass.com.br/operations?page=1461
# Fetching data from https://public.api.spotpass.com.br/operations?page=1462
# Fetching data from https://public.api.spotpass.com.br/operations?page=1463
# Fetching data from https://public.api.spotpass.com.br/operations?page=1464
# Fetching data from https://public.api.spotpass.com.br/operations?page=1465
# Fetching data from https://public.api.spotpass.com.br/operations?page=1466
# Fetching data from https://public.api.spotpass.com.br/operations?page=1467
# Fetching data from https://public.api.spotpass.com.br/operations?page=1468
# Fetching data from https://public.api.spotpass.com.br/operations?page=1469
# Fetching data from https://public.api.spotpass.com.br/operations?page=1470
# Fetching data from https://public.api.spotpass.com.br/operations?page=1471
# Fetching data from https://public.api.spotpass.com.br/operations?page=1472
# Fetching data from https://public.api.spotpass.com.br/operations?page=1473
# Fetching data from https://public.api.spotpass.com.br/operations?page=1474
# Fetching data from https://public.api.spotpass.com.br/operations?page=1475
# Fetching data from https://public.api.spotpass.com.br/operations?page=1476
# Fetching data from https://public.api.spotpass.com.br/operations?page=1477
# Fetching data from https://public.api.spotpass.com.br/operations?page=1478
# Fetching data from https://public.api.spotpass.com.br/operations?page=1479
# Fetching data from https://public.api.spotpass.com.br/operations?page=1480
# Fetching data from https://public.api.spotpass.com.br/operations?page=1481
# Fetching data from https://public.api.spotpass.com.br/operations?page=1482
# Fetching data from https://public.api.spotpass.com.br/operations?page=1483
# Fetching data from https://public.api.spotpass.com.br/operations?page=1484
# Fetching data from https://public.api.spotpass.com.br/operations?page=1485
# Fetching data from https://public.api.spotpass.com.br/operations?page=1486
# Fetching data from https://public.api.spotpass.com.br/operations?page=1487
# Fetching data from https://public.api.spotpass.com.br/operations?page=1488
# Fetching data from https://public.api.spotpass.com.br/operations?page=1489
# Fetching data from https://public.api.spotpass.com.br/operations?page=1490
# Fetching data from https://public.api.spotpass.com.br/operations?page=1491
# Fetching data from https://public.api.spotpass.com.br/operations?page=1492
# Fetching data from https://public.api.spotpass.com.br/operations?page=1493
# Fetching data from https://public.api.spotpass.com.br/operations?page=1494
# Fetching data from https://public.api.spotpass.com.br/operations?page=1495
# Fetching data from https://public.api.spotpass.com.br/operations?page=1496
# Fetching data from https://public.api.spotpass.com.br/operations?page=1497
# Fetching data from https://public.api.spotpass.com.br/operations?page=1498
# Fetching data from https://public.api.spotpass.com.br/operations?page=1499
# Fetching data from https://public.api.spotpass.com.br/operations?page=1500
# Fetching data from https://public.api.spotpass.com.br/operations?page=1501
# Fetching data from https://public.api.spotpass.com.br/operations?page=1502
# Fetching data from https://public.api.spotpass.com.br/operations?page=1503
# Fetching data from https://public.api.spotpass.com.br/operations?page=1504
# Fetching data from https://public.api.spotpass.com.br/operations?page=1505
# Fetching data from https://public.api.spotpass.com.br/operations?page=1506
# Fetching data from https://public.api.spotpass.com.br/operations?page=1507
# Fetching data from https://public.api.spotpass.com.br/operations?page=1508
# Fetching data from https://public.api.spotpass.com.br/operations?page=1509
# Fetching data from https://public.api.spotpass.com.br/operations?page=1510
# Fetching data from https://public.api.spotpass.com.br/operations?page=1511
# Fetching data from https://public.api.spotpass.com.br/operations?page=1512
# Fetching data from https://public.api.spotpass.com.br/operations?page=1513
# Fetching data from https://public.api.spotpass.com.br/operations?page=1514
# Fetching data from https://public.api.spotpass.com.br/operations?page=1515
# Fetching data from https://public.api.spotpass.com.br/operations?page=1516
# Fetching data from https://public.api.spotpass.com.br/operations?page=1517
# Fetching data from https://public.api.spotpass.com.br/operations?page=1518
# Fetching data from https://public.api.spotpass.com.br/operations?page=1519
# Fetching data from https://public.api.spotpass.com.br/operations?page=1520
# Fetching data from https://public.api.spotpass.com.br/operations?page=1521
# Fetching data from https://public.api.spotpass.com.br/operations?page=1522
# Fetching data from https://public.api.spotpass.com.br/operations?page=1523
# Fetching data from https://public.api.spotpass.com.br/operations?page=1524
# Fetching data from https://public.api.spotpass.com.br/operations?page=1525
# Fetching data from https://public.api.spotpass.com.br/operations?page=1526
# Fetching data from https://public.api.spotpass.com.br/operations?page=1527
# Fetching data from https://public.api.spotpass.com.br/operations?page=1528
# Fetching data from https://public.api.spotpass.com.br/operations?page=1529
# Fetching data from https://public.api.spotpass.com.br/operations?page=1530
# Fetching data from https://public.api.spotpass.com.br/operations?page=1531
# Fetching data from https://public.api.spotpass.com.br/operations?page=1532
# Fetching data from https://public.api.spotpass.com.br/operations?page=1533
# Fetching data from https://public.api.spotpass.com.br/operations?page=1534
# Fetching data from https://public.api.spotpass.com.br/operations?page=1535
# Fetching data from https://public.api.spotpass.com.br/operations?page=1536
# Fetching data from https://public.api.spotpass.com.br/operations?page=1537
# Fetching data from https://public.api.spotpass.com.br/operations?page=1538
# Fetching data from https://public.api.spotpass.com.br/operations?page=1539
# Fetching data from https://public.api.spotpass.com.br/operations?page=1540
# Fetching data from https://public.api.spotpass.com.br/operations?page=1541
# Fetching data from https://public.api.spotpass.com.br/operations?page=1542
# Fetching data from https://public.api.spotpass.com.br/operations?page=1543
# Fetching data from https://public.api.spotpass.com.br/operations?page=1544
# Fetching data from https://public.api.spotpass.com.br/operations?page=1545
# Fetching data from https://public.api.spotpass.com.br/operations?page=1546
# Fetching data from https://public.api.spotpass.com.br/operations?page=1547
# Fetching data from https://public.api.spotpass.com.br/operations?page=1548
# Fetching data from https://public.api.spotpass.com.br/operations?page=1549
# Fetching data from https://public.api.spotpass.com.br/operations?page=1550
# Fetching data from https://public.api.spotpass.com.br/operations?page=1551
# Fetching data from https://public.api.spotpass.com.br/operations?page=1552
# Fetching data from https://public.api.spotpass.com.br/operations?page=1553
# Fetching data from https://public.api.spotpass.com.br/operations?page=1554
# Fetching data from https://public.api.spotpass.com.br/operations?page=1555
# Fetching data from https://public.api.spotpass.com.br/operations?page=1556
# Fetching data from https://public.api.spotpass.com.br/operations?page=1557
# Fetching data from https://public.api.spotpass.com.br/operations?page=1558
# Fetching data from https://public.api.spotpass.com.br/operations?page=1559
# Fetching data from https://public.api.spotpass.com.br/operations?page=1560
# Fetching data from https://public.api.spotpass.com.br/operations?page=1561
# Fetching data from https://public.api.spotpass.com.br/operations?page=1562
# Fetching data from https://public.api.spotpass.com.br/operations?page=1563
# Fetching data from https://public.api.spotpass.com.br/operations?page=1564
# Fetching data from https://public.api.spotpass.com.br/operations?page=1565
# Fetching data from https://public.api.spotpass.com.br/operations?page=1566
# Fetching data from https://public.api.spotpass.com.br/operations?page=1567
# Fetching data from https://public.api.spotpass.com.br/operations?page=1568
# Fetching data from https://public.api.spotpass.com.br/operations?page=1569
# Fetching data from https://public.api.spotpass.com.br/operations?page=1570
# Fetching data from https://public.api.spotpass.com.br/operations?page=1571
# Fetching data from https://public.api.spotpass.com.br/operations?page=1572
# Fetching data from https://public.api.spotpass.com.br/operations?page=1573
# Fetching data from https://public.api.spotpass.com.br/operations?page=1574
# Fetching data from https://public.api.spotpass.com.br/operations?page=1575
# Fetching data from https://public.api.spotpass.com.br/operations?page=1576
# Fetching data from https://public.api.spotpass.com.br/operations?page=1577
# Fetching data from https://public.api.spotpass.com.br/operations?page=1578
# Fetching data from https://public.api.spotpass.com.br/operations?page=1579
# Fetching data from https://public.api.spotpass.com.br/operations?page=1580
# Fetching data from https://public.api.spotpass.com.br/operations?page=1581
# Fetching data from https://public.api.spotpass.com.br/operations?page=1582
# Fetching data from https://public.api.spotpass.com.br/operations?page=1583
# Fetching data from https://public.api.spotpass.com.br/operations?page=1584
# Fetching data from https://public.api.spotpass.com.br/operations?page=1585
# Fetching data from https://public.api.spotpass.com.br/operations?page=1586
# Fetching data from https://public.api.spotpass.com.br/operations?page=1587
# Fetching data from https://public.api.spotpass.com.br/operations?page=1588
# Fetching data from https://public.api.spotpass.com.br/operations?page=1589
# Fetching data from https://public.api.spotpass.com.br/operations?page=1590
# Fetching data from https://public.api.spotpass.com.br/operations?page=1591
# Fetching data from https://public.api.spotpass.com.br/operations?page=1592
# Fetching data from https://public.api.spotpass.com.br/operations?page=1593
# Fetching data from https://public.api.spotpass.com.br/operations?page=1594
# Fetching data from https://public.api.spotpass.com.br/operations?page=1595
# Fetching data from https://public.api.spotpass.com.br/operations?page=1596
# Fetching data from https://public.api.spotpass.com.br/operations?page=1597
# Fetching data from https://public.api.spotpass.com.br/operations?page=1598
# Fetching data from https://public.api.spotpass.com.br/operations?page=1599
# Fetching data from https://public.api.spotpass.com.br/operations?page=1600
# Fetching data from https://public.api.spotpass.com.br/operations?page=1601
# Fetching data from https://public.api.spotpass.com.br/operations?page=1602
# Fetching data from https://public.api.spotpass.com.br/operations?page=1603
# Fetching data from https://public.api.spotpass.com.br/operations?page=1604
# Fetching data from https://public.api.spotpass.com.br/operations?page=1605
# Fetching data from https://public.api.spotpass.com.br/operations?page=1606
# Fetching data from https://public.api.spotpass.com.br/operations?page=1607
# Fetching data from https://public.api.spotpass.com.br/operations?page=1608
# Fetching data from https://public.api.spotpass.com.br/operations?page=1609
# Fetching data from https://public.api.spotpass.com.br/operations?page=1610
# Fetching data from https://public.api.spotpass.com.br/operations?page=1611
# Fetching data from https://public.api.spotpass.com.br/operations?page=1612
# Fetching data from https://public.api.spotpass.com.br/operations?page=1613
# Fetching data from https://public.api.spotpass.com.br/operations?page=1614
# Fetching data from https://public.api.spotpass.com.br/operations?page=1615
# Fetching data from https://public.api.spotpass.com.br/operations?page=1616
# Fetching data from https://public.api.spotpass.com.br/operations?page=1617
# Fetching data from https://public.api.spotpass.com.br/operations?page=1618
# Fetching data from https://public.api.spotpass.com.br/operations?page=1619
# Fetching data from https://public.api.spotpass.com.br/operations?page=1620
# Fetching data from https://public.api.spotpass.com.br/operations?page=1621
# Fetching data from https://public.api.spotpass.com.br/operations?page=1622
# Fetching data from https://public.api.spotpass.com.br/operations?page=1623
# Fetching data from https://public.api.spotpass.com.br/operations?page=1624
# Fetching data from https://public.api.spotpass.com.br/operations?page=1625
# Fetching data from https://public.api.spotpass.com.br/operations?page=1626
# Fetching data from https://public.api.spotpass.com.br/operations?page=1627
# Fetching data from https://public.api.spotpass.com.br/operations?page=1628
# Fetching data from https://public.api.spotpass.com.br/operations?page=1629
# Fetching data from https://public.api.spotpass.com.br/operations?page=1630
# Fetching data from https://public.api.spotpass.com.br/operations?page=1631
# Fetching data from https://public.api.spotpass.com.br/operations?page=1632
# Fetching data from https://public.api.spotpass.com.br/operations?page=1633
# Fetching data from https://public.api.spotpass.com.br/operations?page=1634
# Fetching data from https://public.api.spotpass.com.br/operations?page=1635
# Fetching data from https://public.api.spotpass.com.br/operations?page=1636
# Fetching data from https://public.api.spotpass.com.br/operations?page=1637
# Fetching data from https://public.api.spotpass.com.br/operations?page=1638
# Fetching data from https://public.api.spotpass.com.br/operations?page=1639
# Fetching data from https://public.api.spotpass.com.br/operations?page=1640
# Fetching data from https://public.api.spotpass.com.br/operations?page=1641
# Fetching data from https://public.api.spotpass.com.br/operations?page=1642
# Fetching data from https://public.api.spotpass.com.br/operations?page=1643
# Fetching data from https://public.api.spotpass.com.br/operations?page=1644
# Fetching data from https://public.api.spotpass.com.br/operations?page=1645
# Fetching data from https://public.api.spotpass.com.br/operations?page=1646
# Fetching data from https://public.api.spotpass.com.br/operations?page=1647
# Fetching data from https://public.api.spotpass.com.br/operations?page=1648
# Fetching data from https://public.api.spotpass.com.br/operations?page=1649
# Fetching data from https://public.api.spotpass.com.br/operations?page=1650
# Fetching data from https://public.api.spotpass.com.br/operations?page=1651
# Fetching data from https://public.api.spotpass.com.br/operations?page=1652
# Fetching data from https://public.api.spotpass.com.br/operations?page=1653
# Fetching data from https://public.api.spotpass.com.br/operations?page=1654
# Fetching data from https://public.api.spotpass.com.br/operations?page=1655
# Fetching data from https://public.api.spotpass.com.br/operations?page=1656
# Fetching data from https://public.api.spotpass.com.br/operations?page=1657
# Fetching data from https://public.api.spotpass.com.br/operations?page=1658
# Fetching data from https://public.api.spotpass.com.br/operations?page=1659
# Fetching data from https://public.api.spotpass.com.br/operations?page=1660
# Fetching data from https://public.api.spotpass.com.br/operations?page=1661
# Fetching data from https://public.api.spotpass.com.br/operations?page=1662
# Fetching data from https://public.api.spotpass.com.br/operations?page=1663
# Fetching data from https://public.api.spotpass.com.br/operations?page=1664
# Fetching data from https://public.api.spotpass.com.br/operations?page=1665

# %%
display(df)
# Out:
# StatementMeta(, 3a198fef-d98b-41ea-bdeb-d9274de83553, 26, Finished, Available)
# SynapseWidget(Synapse.DataFrame, f42da860-c031-4814-854a-e685c0cf54e8)

# %%
# Assuming you already have the DataFrame loaded as 'df'
row_count = df.count()

# Print the row count
print("Accounts count: {}".format(row_count))
# Out:
# StatementMeta(, 3a198fef-d98b-41ea-bdeb-d9274de83553, 27, Finished, Available)
# Accounts count: 150

# %%
if not df.isEmpty():
    df.write.format("delta")\
    .options(**write_setup)\
    .option("mergeSchema", "true")\
    .option("parquet.vorder.enabled", "force_true")\
    .mode("overwrite")\
    .save(delta_table_name)
# Out:
# StatementMeta(, 3a198fef-d98b-41ea-bdeb-d9274de83553, 28, Finished, Available)

# %%
# %%sql
# SELECT count(*)
# FROM LAKEHOUSE_ELDOURADO.spotpass_operations
# Out:
# StatementMeta(, 3a198fef-d98b-41ea-bdeb-d9274de83553, 32, Finished, Available)
# InterpreterError: Fail to start interpreter.
# detail: requirement failed: SparkContext has been stopped
# error message:

# %%
# %%sql
# SELECT *
# FROM LAKEHOUSE_ELDOURADO.'{delta_table_name}'
# Out:
# StatementMeta(, 3a198fef-d98b-41ea-bdeb-d9274de83553, 30, Finished, Available)
# InterpreterError: Fail to start interpreter.
# detail: requirement failed: SparkContext has been stopped
# error message:
